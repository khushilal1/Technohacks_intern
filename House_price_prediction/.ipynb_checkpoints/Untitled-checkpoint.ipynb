# %% [markdown]
# # Problem Statement
# # 1. Which locations within the King County area have the highest average house prices?
#
# # Understanding what locations to focus the advertising campaign on is key for our stakeholders.
#
# # 2. Which house attributes increase sale price?
#
# # Understanding home buyers' preferences can focus our campaign and help us guide clients willing to undertake renovations prior to selling.
#
# # 3. Does time of the year have an impact on house sales?
#
# # Understanding seasonal trends will influence when the campaign should be launched.

# %% [raw]
# Data
# A dataset has been provided and can be found in the kc_house_data.csv file in this repository.
#
# The column names and descriptions as provided can be found in the column_names.md file in this repository. For convenience they have been reproduced below.
#
# Column Names and descriptions for Kings County Data Set
#
# id - unique identified for a house
# dateDate - house was sold
# pricePrice - is prediction target
# bedroomsNumber - of Bedrooms/House
# bathroomsNumber - of bathrooms/bedrooms
# sqft_livingsquare - footage of the home
# sqft_lotsquare - footage of the lot
# floorsTotal - floors (levels) in house
# waterfront - House which has a view to a waterfront
# view - Has been viewed
# condition - How good the condition is ( Overall )
# grade - overall grade given to the housing unit, based on King County grading system
# sqft_above - square footage of house apart from basement
# sqft_basement - square footage of the basement
# yr_built - Built Year
# yr_renovated - Year when house was renovated
# zipcode - zip
# lat - Latitude coordinate
# long - Longitude coordinate
# sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %%
# Obtain Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#laoding dataset
kc_data=pd.read_csv("kc_house_data.csv")
kc_data.sample(5)
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 3858  2525000690  20150309T000000  347500.0         3       1.75         1620
# 5610  1839900080  20140712T000000  335000.0         3       1.00          950
# 3590  7752200100  20140930T000000  630000.0         4       2.50         2540
# 5636  4027700321  20141028T000000  420000.0         3       1.75         2390
# 3483  8651400750  20141028T000000  209950.0         3       1.75         1100
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 3858      7500     1.0           0     0  ...      7        1220
# 5610      8000     1.0           0     0  ...      7         950
# 3590     11100     1.0           0     0  ...      7        2540
# 5636     11242     1.0           0     0  ...      7        1290
# 3483      5525     1.0           0     0  ...      6        1100
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3858            400      1981             0    98059  47.4815 -122.162
# 5610              0      1968             0    98034  47.7193 -122.184
# 3590              0      1957             0    98008  47.6317 -122.124
# 5636           1100      1959             0    98155  47.7759 -122.272
# 3483              0      1968             0    98042  47.3625 -122.084
#
#       sqft_living15  sqft_lot15
# 3858           1470        7938
# 5610           2270        8540
# 3590           1560       11100
# 5636           2270        9650
# 3483           1050        5200
#
# [5 rows x 21 columns]

# %%
len(kc_data)
# Out:
# 21613

# %% [markdown]
# Our dataset has 21613 prices from house sales in the King County area.

# %% [markdown]
# #Train test split
# Before proceeding further, we wish to split our data into a training set and a testing set. We will first need to seperate features from target and then we will make use of sklearn's train_test_split() function. We will choose to keep 10% of our data for final testing of our mode

# %%
#separate the dependent and target features
X=kc_data.drop("price",axis=1)
y=kc_data["price"]

# %%
#split
from sklearn.model_selection import train_test_split

# %%
#train test split of 10% Data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.10,random_state=42)

# %%
#len of the splited data
print(len(X_train),len(X_test),len(y_train),len(y_test))
# Out:
# 19451 2162 19451 2162

# %%
#trainig data
training_df=pd.concat([X_train,y_train],axis=1)

# %%
training_df.head()
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 6181   2787310130  20141212T000000         4       1.75         2090
# 4688   4358700100  20141202T000000         3       2.50         1450
# 1703   3121069036  20141208T000000         3       1.75         3020
# 21200  1959700225  20150224T000000         3       1.75         1370
# 18874  3205500230  20140811T000000         3       1.75         1330
#
#        sqft_lot  floors  waterfront  view  condition  ...  sqft_above  \
# 6181       7416     1.0           0     0          4  ...        1050
# 4688       5175     1.0           0     0          3  ...        1030
# 1703     360241     2.0           0     0          3  ...        3020
# 21200      1990     3.0           0     0          3  ...        1370
# 18874      7216     1.0           0     0          3  ...        1330
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 6181            1040      1970             0    98031  47.4107 -122.179
# 4688             420      1995             0    98133  47.7082 -122.338
# 1703               0      1992             0    98092  47.2662 -122.088
# 21200              0      2014             0    98102  47.6434 -122.324
# 18874              0      1969             0    98034  47.7199 -122.180
#
#        sqft_living15  sqft_lot15     price
# 6181            1710        7527  289950.0
# 4688            1740        9250  465000.0
# 1703            1890      209959  617000.0
# 21200           1730        1990  720000.0
# 18874           1500        8000  381000.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # cleanig of dataset

# %% [raw]
# INvesting the data type
# #summary of data

# %%
training_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19451 entries, 6181 to 15795
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             19451 non-null  int64
#  1   date           19451 non-null  object
#  2   bedrooms       19451 non-null  int64
#  3   bathrooms      19451 non-null  float64
#  4   sqft_living    19451 non-null  int64
#  5   sqft_lot       19451 non-null  int64
#  6   floors         19451 non-null  float64
#  7   waterfront     19451 non-null  int64
#  8   view           19451 non-null  int64
#  9   condition      19451 non-null  int64
#  10  grade          19451 non-null  int64
#  11  sqft_above     19451 non-null  int64
#  12  sqft_basement  19451 non-null  int64
#  13  yr_built       19451 non-null  int64
#  14  yr_renovated   19451 non-null  int64
#  15  zipcode        19451 non-null  int64
#  16  lat            19451 non-null  float64
#  17  long           19451 non-null  float64
#  18  sqft_living15  19451 non-null  int64
#  19  sqft_lot15     19451 non-null  int64
#  20  price          19451 non-null  float64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.3+ MB

# %% [raw]
# We note that
#
# .date should be changed to a DateTime object, to make it easier to manipulate and extract month of sale
# .sqft_basement should be of type float

# %%
#changing format of date
def change_date_form(training_df):
    training_df['date']=pd.to_datetime(training_df["date"])
    return training_df

# %%
#apply to change format of date
training_df=change_date_form(training_df)

# %%
training_df.head()
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6181   2787310130 2014-12-12         4       1.75         2090      7416
# 4688   4358700100 2014-12-02         3       2.50         1450      5175
# 1703   3121069036 2014-12-08         3       1.75         3020    360241
# 21200  1959700225 2015-02-24         3       1.75         1370      1990
# 18874  3205500230 2014-08-11         3       1.75         1330      7216
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 6181      1.0           0     0          4  ...        1050           1040
# 4688      1.0           0     0          3  ...        1030            420
# 1703      2.0           0     0          3  ...        3020              0
# 21200     3.0           0     0          3  ...        1370              0
# 18874     1.0           0     0          3  ...        1330              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 6181       1970             0    98031  47.4107 -122.179           1710
# 4688       1995             0    98133  47.7082 -122.338           1740
# 1703       1992             0    98092  47.2662 -122.088           1890
# 21200      2014             0    98102  47.6434 -122.324           1730
# 18874      1969             0    98034  47.7199 -122.180           1500
#
#        sqft_lot15     price
# 6181         7527  289950.0
# 4688         9250  465000.0
# 1703       209959  617000.0
# 21200        1990  720000.0
# 18874        8000  381000.0
#
# [5 rows x 21 columns]

# %%
# Investigate sqft_basement column
training_df["sqft_basement"].value_counts()
# Out:
# 0       11851
# 600       203
# 700       198
# 500       186
# 800       184
#         ...
# 295         1
# 2610        1
# 588         1
# 2730        1
# 2250        1
# Name: sqft_basement, Length: 301, dtype: int64

# %%
# Get summary statistics for sqft_basement
training_df["sqft_basement"].astype(float)
# Out:
# 6181     1040.0
# 4688      420.0
# 1703        0.0
# 21200       0.0
# 18874       0.0
#           ...
# 11964       0.0
# 21575       0.0
# 5390        0.0
# 860         0.0
# 15795       0.0
# Name: sqft_basement, Length: 19451, dtype: float64

# %% [markdown]
# # Dealing with null values

# %%
#checkign is there any null  value
training_df.isnull().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %% [markdown]
# # checking duplicate

# %%
training_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate data in our dataset.

# %%
training_df["id"].duplicated().sum()
# Out:
# 145

# %% [markdown]
# It indicate that house of same id may sold much more times

# %% [markdown]
# # Features engineering

# %%
# plt.figure(figsize=(20,15))
# sns.heatmap(training_df.corr(),annot=True,cbar=True,linewidths=.9)
# plt.show()

# %%
training_df.drop("id",axis=1,inplace=True)

# %%
training_df['waterfront'].corr(training_df['condition'])
# Out:
# 0.016123779968162087

# %%
training_df.head()
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6181            0     0          4      7        1050           1040
# 4688            0     0          3      8        1030            420
# 1703            0     0          3      8        3020              0
# 21200           0     0          3      9        1370              0
# 18874           0     0          3      7        1330              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 6181       1970             0    98031  47.4107 -122.179           1710
# 4688       1995             0    98133  47.7082 -122.338           1740
# 1703       1992             0    98092  47.2662 -122.088           1890
# 21200      2014             0    98102  47.6434 -122.324           1730
# 18874      1969             0    98034  47.7199 -122.180           1500
#
#        sqft_lot15     price
# 6181         7527  289950.0
# 4688         9250  465000.0
# 1703       209959  617000.0
# 21200        1990  720000.0
# 18874        8000  381000.0

# %%
# Visualise yr_renovated post 1900 (to not show all the 0 values)
training_df[training_df['yr_renovated'] > 1900]['yr_renovated'].hist()
plt.xlabel("Year")
plt.ylabel('Frequency')
plt.title("Distribution of year renovated feature")
plt.show()

plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Acer\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [raw]
# We will choose to only consider renovations which took place from 1990 onwards, on the basis that earlier renovations are likely to be obsolete. Let us create a new feature was_renovated_post90 which has value 1 if the house was renovated post 1990 and 0 otherwise.

# %%
training_df.columns
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %% [markdown]
# # Numerical FEACTURES

# %%
training_df
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
# ...          ...       ...        ...          ...       ...     ...
# 11964 2014-11-13         3       1.50         1000      6914     1.0
# 21575 2014-11-11         3       2.50         3087      5002     2.0
# 5390  2014-09-30         3       2.50         2120      4780     2.0
# 860   2014-06-20         1       0.75          380     15000     1.0
# 15795 2015-03-25         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6181            0     0          4      7        1050           1040
# 4688            0     0          3      8        1030            420
# 1703            0     0          3      8        3020              0
# 21200           0     0          3      9        1370              0
# 18874           0     0          3      7        1330              0
# ...           ...   ...        ...    ...         ...            ...
# 11964           0     0          3      7        1000              0
# 21575           0     0          3      8        3087              0
# 5390            0     0          3      7        2120              0
# 860             0     0          3      5         380              0
# 15795           0     0          3      7        3130              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 6181       1970             0    98031  47.4107 -122.179           1710
# 4688       1995             0    98133  47.7082 -122.338           1740
# 1703       1992             0    98092  47.2662 -122.088           1890
# 21200      2014             0    98102  47.6434 -122.324           1730
# 18874      1969             0    98034  47.7199 -122.180           1500
# ...         ...           ...      ...      ...      ...            ...
# 11964      1947             0    98125  47.7144 -122.319           1000
# 21575      2014             0    98023  47.2974 -122.349           2927
# 5390       2004             0    98053  47.6810 -122.032           1690
# 860        1963             0    98168  47.4810 -122.323           1170
# 15795      2006             0    98042  47.3837 -122.099           3020
#
#        sqft_lot15     price
# 6181         7527  289950.0
# 4688         9250  465000.0
# 1703       209959  617000.0
# 21200        1990  720000.0
# 18874        8000  381000.0
# ...           ...       ...
# 11964        6947  378000.0
# 21575        5183  399950.0
# 5390         2650  575000.0
# 860         15000  245000.0
# 15795        5997  315000.0
#
# [19451 rows x 20 columns]

# %%
# Define function to create was_renovated_post90 feature
def renovation_feature(df):
    '''Creates bool was_renovated_post90 feature and drops original yr_renovated feature'''
    df['was_renovated_post90'] = df['yr_renovated'].map(lambda x: 1 if x > 1990 else 0)
    return df

# %%
renovation_feature(training_df)
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
# ...          ...       ...        ...          ...       ...     ...
# 11964 2014-11-13         3       1.50         1000      6914     1.0
# 21575 2014-11-11         3       2.50         3087      5002     2.0
# 5390  2014-09-30         3       2.50         2120      4780     2.0
# 860   2014-06-20         1       0.75          380     15000     1.0
# 15795 2015-03-25         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 6181            0     0          4      7  ...           1040      1970
# 4688            0     0          3      8  ...            420      1995
# 1703            0     0          3      8  ...              0      1992
# 21200           0     0          3      9  ...              0      2014
# 18874           0     0          3      7  ...              0      1969
# ...           ...   ...        ...    ...  ...            ...       ...
# 11964           0     0          3      7  ...              0      1947
# 21575           0     0          3      8  ...              0      2014
# 5390            0     0          3      7  ...              0      2004
# 860             0     0          3      5  ...              0      1963
# 15795           0     0          3      7  ...              0      2006
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 6181              0    98031  47.4107 -122.179           1710        7527
# 4688              0    98133  47.7082 -122.338           1740        9250
# 1703              0    98092  47.2662 -122.088           1890      209959
# 21200             0    98102  47.6434 -122.324           1730        1990
# 18874             0    98034  47.7199 -122.180           1500        8000
# ...             ...      ...      ...      ...            ...         ...
# 11964             0    98125  47.7144 -122.319           1000        6947
# 21575             0    98023  47.2974 -122.349           2927        5183
# 5390              0    98053  47.6810 -122.032           1690        2650
# 860               0    98168  47.4810 -122.323           1170       15000
# 15795             0    98042  47.3837 -122.099           3020        5997
#
#           price  was_renovated_post90
# 6181   289950.0                     0
# 4688   465000.0                     0
# 1703   617000.0                     0
# 21200  720000.0                     0
# 18874  381000.0                     0
# ...         ...                   ...
# 11964  378000.0                     0
# 21575  399950.0                     0
# 5390   575000.0                     0
# 860    245000.0                     0
# 15795  315000.0                     0
#
# [19451 rows x 21 columns]

# %%
# Get summary statistics for yr_built
training_df['yr_built'].describe()
# Out:
# count    19451.000000
# mean      1971.063441
# std         29.399033
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %%
sns.boxplot(training_df['yr_built'])
# Out:
# <Axes: ylabel='yr_built'>

# %% [markdown]
# It has no outlier

# %%
training_df["yr_built"].hist()
# Out:
# <Axes: >

# %% [markdown]
# We are going to define bins as the yr_built feature should be treated as a categorical variable. We will use the summary statistics (quartiles) to define our bins, so that we have roughly the same number of data points in each bin.

# %%
#continuous into categorical
0# Define function to map yr_built into bins
def year_built(df):
    ''' Maps yr_built feature into categorical bins'''
    
    # Define bins based on statistics
    yr_built_bins = [1899, 1950, 1975, 1997, 2016]
    yr_built_labels = ['pre1950', '1950_to_1975', '1975_to_1997', '1997_to_2015']
    
    # Map to bins using pd.cut()
    df['yr_built'] = pd.cut(df['yr_built'], bins = yr_built_bins, labels = yr_built_labels)
    
    return df

# %%
#appy for the function
year_built(training_df)
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
# ...          ...       ...        ...          ...       ...     ...
# 11964 2014-11-13         3       1.50         1000      6914     1.0
# 21575 2014-11-11         3       2.50         3087      5002     2.0
# 5390  2014-09-30         3       2.50         2120      4780     2.0
# 860   2014-06-20         1       0.75          380     15000     1.0
# 15795 2015-03-25         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement      yr_built  \
# 6181            0     0          4      7  ...           1040  1950_to_1975
# 4688            0     0          3      8  ...            420  1975_to_1997
# 1703            0     0          3      8  ...              0  1975_to_1997
# 21200           0     0          3      9  ...              0  1997_to_2015
# 18874           0     0          3      7  ...              0  1950_to_1975
# ...           ...   ...        ...    ...  ...            ...           ...
# 11964           0     0          3      7  ...              0       pre1950
# 21575           0     0          3      8  ...              0  1997_to_2015
# 5390            0     0          3      7  ...              0  1997_to_2015
# 860             0     0          3      5  ...              0  1950_to_1975
# 15795           0     0          3      7  ...              0  1997_to_2015
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 6181             0    98031  47.4107 -122.179           1710        7527
# 4688             0    98133  47.7082 -122.338           1740        9250
# 1703             0    98092  47.2662 -122.088           1890      209959
# 21200            0    98102  47.6434 -122.324           1730        1990
# 18874            0    98034  47.7199 -122.180           1500        8000
# ...            ...      ...      ...      ...            ...         ...
# 11964            0    98125  47.7144 -122.319           1000        6947
# 21575            0    98023  47.2974 -122.349           2927        5183
# 5390             0    98053  47.6810 -122.032           1690        2650
# 860              0    98168  47.4810 -122.323           1170       15000
# 15795            0    98042  47.3837 -122.099           3020        5997
#
#           price  was_renovated_post90
# 6181   289950.0                     0
# 4688   465000.0                     0
# 1703   617000.0                     0
# 21200  720000.0                     0
# 18874  381000.0                     0
# ...         ...                   ...
# 11964  378000.0                     0
# 21575  399950.0                     0
# 5390   575000.0                     0
# 860    245000.0                     0
# 15795  315000.0                     0
#
# [19451 rows x 21 columns]

# %%
training_df["yr_built"].hist()
# Out:
# <Axes: >

# %%
# Define function has_basement
def has_basement(df):
    '''creates bool feature has_basement and drops original basement feature'''
    df['has_basement'] = df['sqft_basement'].map(lambda x: 1 if x > 0 else 0)
    df = df.drop('sqft_basement', axis = 1)
    return df

# %%
#appy the function
has_basement(training_df)
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
# ...          ...       ...        ...          ...       ...     ...
# 11964 2014-11-13         3       1.50         1000      6914     1.0
# 21575 2014-11-11         3       2.50         3087      5002     2.0
# 5390  2014-09-30         3       2.50         2120      4780     2.0
# 860   2014-06-20         1       0.75          380     15000     1.0
# 15795 2015-03-25         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  ...      yr_built yr_renovated  \
# 6181            0     0          4      7  ...  1950_to_1975            0
# 4688            0     0          3      8  ...  1975_to_1997            0
# 1703            0     0          3      8  ...  1975_to_1997            0
# 21200           0     0          3      9  ...  1997_to_2015            0
# 18874           0     0          3      7  ...  1950_to_1975            0
# ...           ...   ...        ...    ...  ...           ...          ...
# 11964           0     0          3      7  ...       pre1950            0
# 21575           0     0          3      8  ...  1997_to_2015            0
# 5390            0     0          3      7  ...  1997_to_2015            0
# 860             0     0          3      5  ...  1950_to_1975            0
# 15795           0     0          3      7  ...  1997_to_2015            0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15     price  \
# 6181     98031  47.4107 -122.179           1710        7527  289950.0
# 4688     98133  47.7082 -122.338           1740        9250  465000.0
# 1703     98092  47.2662 -122.088           1890      209959  617000.0
# 21200    98102  47.6434 -122.324           1730        1990  720000.0
# 18874    98034  47.7199 -122.180           1500        8000  381000.0
# ...        ...      ...      ...            ...         ...       ...
# 11964    98125  47.7144 -122.319           1000        6947  378000.0
# 21575    98023  47.2974 -122.349           2927        5183  399950.0
# 5390     98053  47.6810 -122.032           1690        2650  575000.0
# 860      98168  47.4810 -122.323           1170       15000  245000.0
# 15795    98042  47.3837 -122.099           3020        5997  315000.0
#
#        was_renovated_post90  has_basement
# 6181                      0             1
# 4688                      0             1
# 1703                      0             0
# 21200                     0             0
# 18874                     0             0
# ...                     ...           ...
# 11964                     0             0
# 21575                     0             0
# 5390                      0             0
# 860                       0             0
# 15795                     0             0
#
# [19451 rows x 21 columns]

# %%
# Define function has viw
def has_viewed(df):
    '''creates bool feature has_basement and drops original basement feature'''
    df['viewed'] = df['view'].map(lambda x: 1 if x > 0 else 0)
    df = df.drop('sqft_basement', axis = 1)
    return df

# %%
#appy function
has_viewed(training_df)
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6181  2014-12-12         4       1.75         2090      7416     1.0
# 4688  2014-12-02         3       2.50         1450      5175     1.0
# 1703  2014-12-08         3       1.75         3020    360241     2.0
# 21200 2015-02-24         3       1.75         1370      1990     3.0
# 18874 2014-08-11         3       1.75         1330      7216     1.0
# ...          ...       ...        ...          ...       ...     ...
# 11964 2014-11-13         3       1.50         1000      6914     1.0
# 21575 2014-11-11         3       2.50         3087      5002     2.0
# 5390  2014-09-30         3       2.50         2120      4780     2.0
# 860   2014-06-20         1       0.75          380     15000     1.0
# 15795 2015-03-25         4       2.50         3130      5999     2.0
#
#        waterfront  view  condition  grade  ...  yr_renovated zipcode      lat  \
# 6181            0     0          4      7  ...             0   98031  47.4107
# 4688            0     0          3      8  ...             0   98133  47.7082
# 1703            0     0          3      8  ...             0   98092  47.2662
# 21200           0     0          3      9  ...             0   98102  47.6434
# 18874           0     0          3      7  ...             0   98034  47.7199
# ...           ...   ...        ...    ...  ...           ...     ...      ...
# 11964           0     0          3      7  ...             0   98125  47.7144
# 21575           0     0          3      8  ...             0   98023  47.2974
# 5390            0     0          3      7  ...             0   98053  47.6810
# 860             0     0          3      5  ...             0   98168  47.4810
# 15795           0     0          3      7  ...             0   98042  47.3837
#
#           long  sqft_living15  sqft_lot15     price  was_renovated_post90  \
# 6181  -122.179           1710        7527  289950.0                     0
# 4688  -122.338           1740        9250  465000.0                     0
# 1703  -122.088           1890      209959  617000.0                     0
# 21200 -122.324           1730        1990  720000.0                     0
# 18874 -122.180           1500        8000  381000.0                     0
# ...        ...            ...         ...       ...                   ...
# 11964 -122.319           1000        6947  378000.0                     0
# 21575 -122.349           2927        5183  399950.0                     0
# 5390  -122.032           1690        2650  575000.0                     0
# 860   -122.323           1170       15000  245000.0                     0
# 15795 -122.099           3020        5997  315000.0                     0
#
#        has_basement  viewed
# 6181              1       0
# 4688              1       0
# 1703              0       0
# 21200             0       0
# 18874             0       0
# ...             ...     ...
# 11964             0       0
# 21575             0       0
# 5390              0       0
# 860               0       0
# 15795             0       0
#
# [19451 rows x 22 columns]

# %%
#bathroom featurex
training_df['bathrooms'].describe()
# Out:
# count    19451.000000
# mean         2.114698
# std          0.770724
# min          0.000000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max          8.000000
# Name: bathrooms, dtype: float64
